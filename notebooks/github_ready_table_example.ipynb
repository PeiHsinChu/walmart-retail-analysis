# %% [markdown]
# ### 平均異常日銷售統計表
#
# | 年份 | 出現次數 | 異常總銷售額 | 平均異常倍數 |
# |------|----------|--------------|---------------|
# | 2020 |    2     |     4453     |     2.19      |
# | 2021 |    3     |     8991     |     2.19      |
# | 2022 |    6     |    14446     |     2.21      |
# | 2023 |    6     |    14435     |     2.22      |
#
# （此表格為 GitHub / Jupyter Notebook 標準格式，排版固定，不會亂掉）
